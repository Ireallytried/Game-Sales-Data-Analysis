# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# read data
df=pd.read_csv('games.csv')

# %%
# check size
df.shape
# Out:
# (16719, 16)

# %%
# brief look at columns and thier data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# We can change data type for column 'Platform' to category and reduce memory usage

# %%
df.Platform = df.Platform.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  category
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: category(1), float64(9), object(6)
# memory usage: 1.9+ MB

# %% [markdown]
# Let's do the same for 'Genre'

# %%
df.Genre.nunique()
# Out:
# 12

# %%
df.Genre = df.Genre.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  category
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  category
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: category(2), float64(9), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# Now we are not using as much memory. Let's see how the dataframe looks like

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %% [markdown]
# Not sure what does column 'Rating' mean.

# %%
# check values for column Rating
df.Rating.value_counts(dropna=False)
# Out:
# NaN     6769
# E       3991
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: Rating, dtype: int64

# %% [markdown]
# After googling I find out that each these letters are responsible for ages since when kids are allowed to play."RP" means that there is no rating yet, we can replace it with 'NAN'

# %%
# replace values
df['Rating']=df.Rating.replace('RP', np.NaN)

# %%
# check if everything is correct
df.Rating.value_counts(dropna=False)
# Out:
# NaN     6772
# E       3991
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# AO         1
# Name: Rating, dtype: int64

# %%
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6772
# dtype: int64

# %%
# delete missing values from columns 'Name', 'Genre' nad 'Publisher'
df = df.dropna(subset=['Name', 'Genre', 'Publisher']).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release     247
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8530
# Critic_Count       8530
# User_Score         6656
# User_Count         9079
# Developer          6576
# Rating             6723
# dtype: int64

# %%
df[df['Year_of_Release'].isna()]
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 608                       Space Invaders     2600              NaN
# 626                            Rock Band     X360              NaN
# ...                                  ...      ...              ...
# 16321  PDC World Championship Darts 2008      PSP              NaN
# 16354                      Freaky Flyers       GC              NaN
# 16397                          Inversion       PC              NaN
# 16407        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16471                       Virtua Quest       GC              NaN
#
#               Genre                               Publisher  NA_Sales  \
# 183          Sports                         Electronic Arts      4.26
# 377          Sports                         Electronic Arts      0.59
# 456          Action  Warner Bros. Interactive Entertainment      1.80
# 608         Shooter                                   Atari      2.36
# 626            Misc                         Electronic Arts      1.93
# ...             ...                                     ...       ...
# 16321        Sports                      Oxygen Interactive      0.01
# 16354        Racing                                 Unknown      0.01
# 16397       Shooter                      Namco Bandai Games      0.01
# 16407     Adventure                                 Unknown      0.01
# 16471  Role-Playing                                 Unknown      0.01
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 183        0.26      0.01         0.71          5.23          94.0
# 377        2.36      0.04         0.51          3.49          84.0
# 456        0.97      0.00         0.29          3.06          74.0
# 608        0.14      0.00         0.03          2.53           NaN
# 626        0.33      0.00         0.21          2.47          92.0
# ...         ...       ...          ...           ...           ...
# 16321      0.00      0.00         0.00          0.01          43.0
# 16354      0.00      0.00         0.00          0.01          69.0
# 16397      0.00      0.00         0.00          0.01          59.0
# 16407      0.00      0.00         0.00          0.01           NaN
# 16471      0.00      0.00         0.00          0.01          55.0
#
#        Critic_Count User_Score  User_Count                     Developer  \
# 183            29.0        8.5       140.0                    EA Tiburon
# 377            20.0        6.4        76.0                     EA Canada
# 456            17.0        7.9        22.0             Traveller's Tales
# 608             NaN        NaN         NaN                           NaN
# 626            72.0        8.2       178.0        Harmonix Music Systems
# ...             ...        ...         ...                           ...
# 16321           7.0        tbd         NaN            Oxygen Interactive
# 16354          14.0        6.5         6.0                        Midway
# 16397           6.0        6.7       107.0             Saber Interactive
# 16407           NaN        NaN         NaN                           NaN
# 16471          19.0        5.5        12.0  Artificial Mind and Movement
#
#       Rating
# 183        E
# 377        E
# 456     E10+
# 608      NaN
# 626        T
# ...      ...
# 16321   E10+
# 16354      T
# 16397      M
# 16407    NaN
# 16471      T
#
# [247 rows x 16 columns]

# %% [markdown]
# Sometimes column 'Name' has its 'Year_of_Release' while it is missing in 'Year_of_Release' column, let's extract it

# %%
# by using regex which extracts 4 last digits from column "Name" we can try to increase number of vaues in column 'Year_of_Release'
df['Year_of_Release'] = df['Year_of_Release'].fillna(df['Name'].str.extract(r'(\d{4})', expand=False).astype(float))

# %%
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release     231
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8530
# Critic_Count       8530
# User_Score         6656
# User_Count         9079
# Developer          6576
# Rating             6723
# dtype: int64

# %% [markdown]
# Now there are less missing values in this column, let's take a look if we can do something else

# %%
df[df['Year_of_Release'].isna()].head(25)
# Out:
#                                              Name Platform  Year_of_Release  \
# 456                    LEGO Batman: The Videogame      Wii              NaN
# 608                                Space Invaders     2600              NaN
# 626                                     Rock Band     X360              NaN
# 656      Frogger's Adventures: Temple of the Frog      GBA              NaN
# 676   LEGO Indiana Jones: The Original Adventures      Wii              NaN
# 717                                Call of Duty 3      Wii              NaN
# 803                                     Rock Band      Wii              NaN
# 1129                      Call of Duty: Black Ops       PC              NaN
# 1140                                    Rock Band      PS3              NaN
# 1503                                    Adventure     2600              NaN
# 1535                   LEGO Batman: The Videogame      PSP              NaN
# 1582                                       Combat     2600              NaN
# 1606                 LEGO Harry Potter: Years 5-7      Wii              NaN
# 1695                    Hitman 2: Silent Assassin       XB              NaN
# 1836                                    Rock Band      PS2              NaN
# 1980                  Legacy of Kain: Soul Reaver       PS              NaN
# 2006                         Donkey Kong Land III       GB              NaN
# 2102                               Air-Sea Battle     2600              NaN
# 2104                                 Suikoden III      PS2              NaN
# 2128                 LEGO Harry Potter: Years 5-7     X360              NaN
# 2153                             Wheel of Fortune      PS2              NaN
# 2165                                     Yakuza 4      PS3              NaN
# 2268                 LEGO Harry Potter: Years 5-7      PS3              NaN
# 2276                                 Namco Museum       XB              NaN
# 2356                                Rhythm Heaven      Wii              NaN
#
#              Genre                               Publisher  NA_Sales  \
# 456         Action  Warner Bros. Interactive Entertainment      1.80
# 608        Shooter                                   Atari      2.36
# 626           Misc                         Electronic Arts      1.93
# 656      Adventure            Konami Digital Entertainment      2.15
# 676         Action                               LucasArts      1.51
# 717        Shooter                              Activision      1.17
# 803           Misc                               MTV Games      1.33
# 1129       Shooter                              Activision      0.58
# 1140          Misc                         Electronic Arts      0.99
# 1503     Adventure                                   Atari      1.21
# 1535        Action  Warner Bros. Interactive Entertainment      0.57
# 1582        Action                                   Atari      1.17
# 1606        Action  Warner Bros. Interactive Entertainment      0.69
# 1695        Action                       Eidos Interactive      0.76
# 1836          Misc                         Electronic Arts      0.71
# 1980        Action                       Eidos Interactive      0.58
# 2006      Platform                                Nintendo      0.68
# 2102       Shooter                                   Atari      0.91
# 2104  Role-Playing                                 Unknown      0.29
# 2128        Action  Warner Bros. Interactive Entertainment      0.51
# 2153          Misc                                 Unknown      0.47
# 2165        Action                                    Sega      0.15
# 2268        Action  Warner Bros. Interactive Entertainment      0.36
# 2276          Misc                                 Unknown      0.77
# 2356          Misc                                 Unknown      0.11
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 456       0.97      0.00         0.29          3.06          74.0
# 608       0.14      0.00         0.03          2.53           NaN
# 626       0.33      0.00         0.21          2.47          92.0
# 656       0.18      0.00         0.07          2.39          73.0
# 676       0.61      0.00         0.21          2.34          78.0
# 717       0.84      0.00         0.23          2.24          69.0
# 803       0.56      0.00         0.20          2.08          80.0
# 1129      0.81      0.00         0.23          1.63          81.0
# 1140      0.41      0.00         0.22          1.62          92.0
# 1503      0.08      0.00         0.01          1.30           NaN
# 1535      0.44      0.00         0.27          1.28          73.0
# 1582      0.07      0.00         0.01          1.25           NaN
# 1606      0.42      0.00         0.12          1.24          76.0
# 1695      0.38      0.00         0.05          1.19          84.0
# 1836      0.06      0.00         0.35          1.11          82.0
# 1980      0.40      0.00         0.07          1.04          91.0
# 2006      0.31      0.00         0.04          1.03           NaN
# 2102      0.06      0.00         0.01          0.98           NaN
# 2104      0.23      0.38         0.08          0.98          86.0
# 2128      0.37      0.00         0.09          0.97          77.0
# 2153      0.36      0.00         0.12          0.95           NaN
# 2165      0.13      0.63         0.05          0.95          78.0
# 2268      0.41      0.00         0.15          0.91          76.0
# 2276      0.11      0.00         0.04          0.91          59.0
# 2356      0.00      0.77         0.01          0.88           NaN
#
#       Critic_Count User_Score  User_Count  \
# 456           17.0        7.9        22.0
# 608            NaN        NaN         NaN
# 626           72.0        8.2       178.0
# 656            4.0        tbd         NaN
# 676           22.0        6.6        28.0
# 717           42.0        6.7        61.0
# 803           21.0        6.3        37.0
# 1129          29.0        5.2      1651.0
# 1140          35.0        8.4       107.0
# 1503           NaN        NaN         NaN
# 1535           5.0        7.4        10.0
# 1582           NaN        NaN         NaN
# 1606           8.0        7.8        13.0
# 1695          23.0          8        19.0
# 1836           8.0        6.8        13.0
# 1980          17.0          9       132.0
# 2006           NaN        NaN         NaN
# 2102           NaN        NaN         NaN
# 2104          23.0        7.7       113.0
# 2128          35.0        7.9        39.0
# 2153           NaN        tbd         NaN
# 2165          59.0          8       177.0
# 2268          27.0        8.3        48.0
# 2276           7.0        tbd         NaN
# 2356           NaN        NaN         NaN
#
#                                  Developer Rating
# 456                      Traveller's Tales   E10+
# 608                                    NaN    NaN
# 626                 Harmonix Music Systems      T
# 656   Konami Computer Entertainment Hawaii      E
# 676                      Traveller's Tales   E10+
# 717                                  Exakt      T
# 803                 Harmonix Music Systems      T
# 1129                              Treyarch      M
# 1140                Harmonix Music Systems      T
# 1503                                   NaN    NaN
# 1535                     Traveller's Tales   E10+
# 1582                                   NaN    NaN
# 1606                     Traveller's Tales   E10+
# 1695                        Io Interactive      M
# 1836                Harmonix Music Systems      T
# 1980                      Crystal Dynamics      T
# 2006                                   NaN    NaN
# 2102                                   NaN    NaN
# 2104                                  KCET      T
# 2128                     Traveller's Tales   E10+
# 2153                                 Atari      E
# 2165                 Ryu ga Gotoku Studios      M
# 2268                     Traveller's Tales   E10+
# 2276                            Mass Media      E
# 2356                                   NaN    NaN

# %%
df[df['Year_of_Release'].isna()].tail(15)
# Out:
#                                           Name Platform  Year_of_Release  \
# 15707                             Virtua Quest      PS2              NaN
# 15748  Shonen Jump's Yu-Gi-Oh! GX Card Almanac       DS              NaN
# 15769                          Without Warning       XB              NaN
# 15919          Dinotopia: The Sunstone Odyssey       GC              NaN
# 15951                              Jet Impulse       DS              NaN
# 16011                   Dance! It's Your Stage      Wii              NaN
# 16032             Ferrari: The Race Experience      Wii              NaN
# 16109             Aquaman: Battle for Atlantis       XB              NaN
# 16132        WRC: FIA World Rally Championship       PC              NaN
# 16240                                   Shorts       DS              NaN
# 16296             Agarest Senki: Re-appearance      PS3              NaN
# 16354                            Freaky Flyers       GC              NaN
# 16397                                Inversion       PC              NaN
# 16407              Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16471                             Virtua Quest       GC              NaN
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# 15707  Role-Playing                       Unknown      0.01      0.01
# 15748          Misc  Konami Digital Entertainment      0.00      0.00
# 15769       Shooter                        Capcom      0.01      0.00
# 15919        Action                       Unknown      0.01      0.00
# 15951    Simulation                      Nintendo      0.00      0.00
# 16011          Misc             DTP Entertainment      0.00      0.01
# 16032        Racing      System 3 Arcade Software      0.00      0.01
# 16109        Action                       Unknown      0.01      0.00
# 16132        Racing              Black Bean Games      0.00      0.01
# 16240      Platform                       Unknown      0.01      0.00
# 16296  Role-Playing                  Idea Factory      0.00      0.00
# 16354        Racing                       Unknown      0.01      0.00
# 16397       Shooter            Namco Bandai Games      0.01      0.00
# 16407     Adventure                       Unknown      0.01      0.00
# 16471  Role-Playing                       Unknown      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 15707      0.00          0.0          0.02          53.0          17.0
# 15748      0.02          0.0          0.02           NaN           NaN
# 15769      0.00          0.0          0.02          45.0          25.0
# 15919      0.00          0.0          0.02          50.0           4.0
# 15951      0.02          0.0          0.02           NaN           NaN
# 16011      0.00          0.0          0.02           NaN           NaN
# 16032      0.00          0.0          0.01          54.0           4.0
# 16109      0.00          0.0          0.01          26.0          13.0
# 16132      0.00          0.0          0.01          65.0           7.0
# 16240      0.00          0.0          0.01           NaN           NaN
# 16296      0.01          0.0          0.01           NaN           NaN
# 16354      0.00          0.0          0.01          69.0          14.0
# 16397      0.00          0.0          0.01          59.0           6.0
# 16407      0.00          0.0          0.01           NaN           NaN
# 16471      0.00          0.0          0.01          55.0          19.0
#
#       User_Score  User_Count                     Developer Rating
# 15707        7.6         5.0  Artificial Mind and Movement      T
# 15748        NaN         NaN                           NaN    NaN
# 15769          2         5.0                        CiRCLE      M
# 15919        tbd         NaN                 Vicious Cycle      T
# 15951        NaN         NaN                           NaN    NaN
# 16011        NaN         NaN                           NaN    NaN
# 16032        NaN         NaN                      System 3      E
# 16109        2.7        15.0                 Lucky Chicken      T
# 16132        NaN         NaN              Black Bean Games    NaN
# 16240        tbd         NaN  Artificial Mind and Movement   E10+
# 16296        NaN         NaN                           NaN    NaN
# 16354        6.5         6.0                        Midway      T
# 16397        6.7       107.0             Saber Interactive      M
# 16407        NaN         NaN                           NaN    NaN
# 16471        5.5        12.0  Artificial Mind and Movement      T

# %% [markdown]
# Seems like we do not have any other possibilities to replace NaNs

# %%
df = df.dropna(subset=['Year_of_Release']).reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8438
# Critic_Count       8438
# User_Score         6583
# User_Count         8961
# Developer          6516
# Rating             6655
# dtype: int64

# %% [markdown]
# Column 'Critic_Count' responsible for saying how many critics gave their score to the current game. Is there any sense to store scores for games where only 1 or 2 critics have voted ?

# %%
df.Critic_Count.mean()
# Out:
# 26.427320490367777

# %% [markdown]
# On average we have 26 critics per game

# %%
df[df['Critic_Count']<3]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %% [markdown]
# Let's do the same for User_Count

# %%
df[df['User_Count']<3]
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year_of_Release, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales, Critic_Score, Critic_Count, User_Score, User_Count, Developer, Rating]
# Index: []

# %% [markdown]
# Ok, so we do not have situations when the score of the game is based on 1 or 2 people, now we can remove these columns

# %%
df = df.drop(columns=['Critic_Count', 'User_Count'])

# %%
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8438
# User_Score         6583
# Developer          6516
# Rating             6655
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16432 entries, 0 to 16431
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16432 non-null  object
#  1   Platform         16432 non-null  category
#  2   Year_of_Release  16432 non-null  float64
#  3   Genre            16432 non-null  category
#  4   Publisher        16432 non-null  object
#  5   NA_Sales         16432 non-null  float64
#  6   EU_Sales         16432 non-null  float64
#  7   JP_Sales         16432 non-null  float64
#  8   Other_Sales      16432 non-null  float64
#  9   Global_Sales     16432 non-null  float64
#  10  Critic_Score     7994 non-null   float64
#  11  User_Score       9849 non-null   object
#  12  Developer        9916 non-null   object
#  13  Rating           9777 non-null   object
# dtypes: category(2), float64(7), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# Hmm, User_Score has object data type, but it should be float

# %%
df.User_Score.value_counts()
# Out:
# tbd    2378
# 7.8     322
# 8       285
# 8.2     277
# 8.3     252
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: User_Score, Length: 96, dtype: int64

# %% [markdown]
# We need to replace 'tbd' with NaN, 'tbd' does not give us any information

# %%
df.User_Score = df.User_Score.replace('tbd', np.NaN)

# %%
df.User_Score.value_counts()
# Out:
# 7.8    322
# 8      285
# 8.2    277
# 8.3    252
# 8.5    249
#       ...
# 1.5      2
# 0.3      2
# 1.1      2
# 0        1
# 9.7      1
# Name: User_Score, Length: 95, dtype: int64

# %%
df.User_Score = df.User_Score.astype( 'float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16432 entries, 0 to 16431
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16432 non-null  object
#  1   Platform         16432 non-null  category
#  2   Year_of_Release  16432 non-null  float64
#  3   Genre            16432 non-null  category
#  4   Publisher        16432 non-null  object
#  5   NA_Sales         16432 non-null  float64
#  6   EU_Sales         16432 non-null  float64
#  7   JP_Sales         16432 non-null  float64
#  8   Other_Sales      16432 non-null  float64
#  9   Global_Sales     16432 non-null  float64
#  10  Critic_Score     7994 non-null   float64
#  11  User_Score       7471 non-null   float64
#  12  Developer        9916 non-null   object
#  13  Rating           9777 non-null   object
# dtypes: category(2), float64(8), object(4)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8438
# User_Score         8961
# Developer          6516
# Rating             6655
# dtype: int64

# %% [markdown]
# We have a lot of missing values for columns 'Critic_Score' and 'User_Score'. We can try to find correlation between scores and sales in different regions.

# %%
NA_c = df['NA_Sales'].corr(df['Critic_Score'])
print(NA_c, 'corr in NA')
EU_c = df['EU_Sales'].corr(df['Critic_Score'])
print(EU_c, 'corr in EU')
JP_c = df['JP_Sales'].corr(df['Critic_Score'])
print(JP_c, 'corr in JP')
Other_c = df['Other_Sales'].corr(df['Critic_Score'])
print(Other_c, 'corr in Other')
Global_c = df['Global_Sales'].corr(df['Critic_Score'])
print(Global_c, 'corr in Global')
# Out:
# 0.24066820993617297 corr in NA
# 0.2214014669796582 corr in EU
# 0.15317741223126294 corr in JP
# 0.19888851855769324 corr in Other
# 0.24575127364307878 corr in Global

# %% [markdown]
# All correlations are too small, let's do the same with User_Score

# %%
NA_c = df['NA_Sales'].corr(df['User_Score'])
print(NA_c, 'corr in NA')
EU_c = df['EU_Sales'].corr(df['User_Score'])
print(EU_c, 'corr in EU')
JP_c = df['JP_Sales'].corr(df['User_Score'])
print(JP_c, 'corr in JP')
Other_c = df['Other_Sales'].corr(df['User_Score'])
print(Other_c, 'corr in Other')
Global_c = df['Global_Sales'].corr(df['User_Score'])
print(Global_c, 'corr in Global')
# Out:
# 0.08570359558394258 corr in NA
# 0.05509865754209435 corr in EU
# 0.12607109252494403 corr in JP
# 0.05684477341126955 corr in Other
# 0.08784045253513086 corr in Global

# %% [markdown]
# Same thing here. I am thinking about another option

# %%
df.Genre.value_counts().count()
# Out:
# 12

# %% [markdown]
# We have 12 unique genres. Let's replace each of them with integer and then we will try to find correlations.

# %%
df.Genre.value_counts()
# Out:
# Action          3308
# Sports          2318
# Misc            1697
# Role-Playing    1483
# Shooter         1296
# Adventure       1291
# Racing          1228
# Platform         878
# Simulation       855
# Fighting         837
# Strategy         672
# Puzzle           569
# Name: Genre, dtype: int64

# %%
# create dictionary for each genre
genre_dict = { 'Action':1, 
              'Sports':2 , 
              'Misc':3 , 
              'Role-Playing':4, 
              'Shooter':5, 
              'Adventure':6, 
              'Racing':7, 
              'Platform':8, 
              'Simulation':9,
              'Fighting':10,
              'Strategy':11,
              'Puzzle':12}

# %%
# create new numeric genre column based on integer value of each genre 
df['Genre_numeric'] = df['Genre'].map(genre_dict)

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16427  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16428               LMA Manager 2007     X360           2006.0        Sports
# 16429        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16430               Spirits & Spells      GBA           2003.0      Platform
# 16431            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16427    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16428   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16429  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16430       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16431    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  User_Score Developer Rating Genre_numeric
# 0              76.0         8.0  Nintendo      E             2
# 1               NaN         NaN       NaN    NaN             8
# 2              82.0         8.3  Nintendo      E             7
# 3              80.0         8.0  Nintendo      E             2
# 4               NaN         NaN       NaN    NaN             4
# ...             ...         ...       ...    ...           ...
# 16427           NaN         NaN       NaN    NaN             1
# 16428           NaN         NaN       NaN    NaN             2
# 16429           NaN         NaN       NaN    NaN             6
# 16430           NaN         NaN       NaN    NaN             8
# 16431           NaN         NaN       NaN    NaN             9
#
# [16432 rows x 15 columns]

# %%
G_u = df['Genre_numeric'].corr(df['User_Score'])
print(G_u, 'corr User')
G_c = df['Genre_numeric'].corr(df['Critic_Score'])
print(G_c, 'corr Critic')
# Out:
# 0.04842453228410118 corr User
# 0.013849965429912894 corr Critic

# %% [markdown]
# Unfortunately in this way it also does not work

# %%
df=df.drop(columns='Genre_numeric')

# %%
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16427  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16428               LMA Manager 2007     X360           2006.0        Sports
# 16429        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16430               Spirits & Spells      GBA           2003.0      Platform
# 16431            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16427    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16428   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16429  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16430       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16431    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  User_Score Developer Rating
# 0              76.0         8.0  Nintendo      E
# 1               NaN         NaN       NaN    NaN
# 2              82.0         8.3  Nintendo      E
# 3              80.0         8.0  Nintendo      E
# 4               NaN         NaN       NaN    NaN
# ...             ...         ...       ...    ...
# 16427           NaN         NaN       NaN    NaN
# 16428           NaN         NaN       NaN    NaN
# 16429           NaN         NaN       NaN    NaN
# 16430           NaN         NaN       NaN    NaN
# 16431           NaN         NaN       NaN    NaN
#
# [16432 rows x 14 columns]

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('games_visualization.csv')

# %% [markdown]
# This is the end of our work in Pandas. Now, let's move to Power BI
